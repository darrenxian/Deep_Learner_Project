# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.applications.inception_v3 import decode_predictions
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
model = InceptionV3(weights='imagenet', include_top=True)

# %%
list_dir = os.listdir('C:/Users/Public/Documents/PNAS2018Images/SeparatedImages/')

# %%
if list_dir[0] == '.ipynb_checkpoints':
    list_dir = list_dir[1:]

# %%
for i in range(0,40,2):
	
	img_path = 'C:/Users/Public/Documents/PNAS2018Images/SeparatedImages/' + list_dir[i]
    
	
	img = image.load_img(img_path, target_size=(299, 299))
	x = image.img_to_array(img)
	x = np.expand_dims(x, axis = 0)
	x = preprocess_input(x)
	
	features = model.predict(x)
	print(decode_predictions(features, top = 3))
	
	plt.imshow(image.load_img(img_path))
	plt.show()
# Out:
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# [[('n04325704', 'stole', 0.36834255), ('n03595614', 'jersey', 0.06731118), ('n02963159', 'cardigan', 0.044348635)]]
# [[('n03595614', 'jersey', 0.9052261), ('n02804610', 'bassoon', 0.010960849), ('n03838899', 'oboe', 0.006201828)]]
# [[('n03595614', 'jersey', 0.09432768), ('n02786058', 'Band_Aid', 0.06170473), ('n02883205', 'bow_tie', 0.03932658)]]
# [[('n03595614', 'jersey', 0.83119595), ('n03476991', 'hair_spray', 0.03355716), ('n04584207', 'wig', 0.010293547)]]
# [[('n03595614', 'jersey', 0.065676555), ('n02804610', 'bassoon', 0.04719969), ('n04370456', 'sweatshirt', 0.029265087)]]
# [[('n03595614', 'jersey', 0.23829778), ('n02804610', 'bassoon', 0.06265061), ('n03394916', 'French_horn', 0.046183843)]]
# [[('n02804610', 'bassoon', 0.047735885), ('n03838899', 'oboe', 0.041647), ('n03595614', 'jersey', 0.03103888)]]
# ...
